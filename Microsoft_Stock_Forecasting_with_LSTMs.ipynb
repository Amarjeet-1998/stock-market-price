# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarjeet-1998/stock-market-price/blob/main/Microsoft_Stock_Forecasting_with_LSTMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/MSFT.csv')

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.061109
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.063292
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064384
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062746
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061655
# ...          ...         ...         ...         ...         ...         ...
# 9157  2022-07-13  250.190002  253.550003  248.110001  252.720001  252.720001
# 9158  2022-07-14  250.570007  255.139999  245.940002  254.080002  254.080002
# 9159  2022-07-15  255.720001  260.369995  254.770004  256.720001  256.720001
# 9160  2022-07-18  259.750000  260.839996  253.300003  254.250000  254.250000
# 9161  2022-07-19  257.579987  259.720001  253.679993  259.529999  259.529999
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9157    29497400
# 9158    25102800
# 9159    29572500
# 9160    20975000
# 9161    24955100
#
# [9162 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9157  2022-07-13  252.720001
# 9158  2022-07-14  254.080002
# 9159  2022-07-15  256.720001
# 9160  2022-07-18  254.250000
# 9161  2022-07-19  259.529999
#
# [9162 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9157    2022-07-13
# 9158    2022-07-14
# 9159    2022-07-15
# 9160    2022-07-18
# 9161    2022-07-19
# Name: Date, Length: 9162, dtype: object

# %%
import datetime

def str_to_Datetime(s):
  split= s.split('-')
  year, month, day = int(split[0]), int(split[1]),int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_Datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9157  2022-07-13  252.720001
# 9158  2022-07-14  254.080002
# 9159  2022-07-15  256.720001
# 9160  2022-07-18  254.250000
# 9161  2022-07-19  259.529999
#
# [9162 rows x 2 columns]

# %%
df['Date']= df['Date'].apply(str_to_Datetime)
df['Date']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9157   2022-07-13
# 9158   2022-07-14
# 9159   2022-07-15
# 9160   2022-07-18
# 9161   2022-07-19
# Name: Date, Length: 9162, dtype: datetime64[ns]

# %%
df
# Out:
#            Date       Close
# 0    1986-03-13    0.097222
# 1    1986-03-14    0.100694
# 2    1986-03-17    0.102431
# 3    1986-03-18    0.099826
# 4    1986-03-19    0.098090
# ...         ...         ...
# 9157 2022-07-13  252.720001
# 9158 2022-07-14  254.080002
# 9159 2022-07-15  256.720001
# 9160 2022-07-18  254.250000
# 9161 2022-07-19  259.529999
#
# [9162 rows x 2 columns]

# %%
df.index = df.pop("Date")
df.index
# Out:
# DatetimeIndex(['1986-03-13', '1986-03-14', '1986-03-17', '1986-03-18',
#                '1986-03-19', '1986-03-20', '1986-03-21', '1986-03-24',
#                '1986-03-25', '1986-03-26',
#                ...
#                '2022-07-06', '2022-07-07', '2022-07-08', '2022-07-11',
#                '2022-07-12', '2022-07-13', '2022-07-14', '2022-07-15',
#                '2022-07-18', '2022-07-19'],
#               dtype='datetime64[ns]', name='Date', length=9162, freq=None)

# %%
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2022-07-13  252.720001
# 2022-07-14  254.080002
# 2022-07-15  256.720001
# 2022-07-18  254.250000
# 2022-07-19  259.529999
#
# [9162 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_Datetime(first_date_str)
  last_date  = str_to_Datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 78ms/step - loss: 84333.5391 - mean_absolute_error: 288.6594 - val_loss: 92012.5625 - val_mean_absolute_error: 303.2484
# Epoch 2/100
# 7/7 [==============================] - 0s 6ms/step - loss: 84100.3516 - mean_absolute_error: 288.2545 - val_loss: 91763.5781 - val_mean_absolute_error: 302.8376
# Epoch 3/100
# 7/7 [==============================] - 0s 6ms/step - loss: 83851.1406 - mean_absolute_error: 287.8199 - val_loss: 91472.8828 - val_mean_absolute_error: 302.3572
# Epoch 4/100
# 7/7 [==============================] - 0s 6ms/step - loss: 83545.5000 - mean_absolute_error: 287.2868 - val_loss: 91077.2500 - val_mean_absolute_error: 301.7023
# Epoch 5/100
# 7/7 [==============================] - 0s 6ms/step - loss: 83103.0156 - mean_absolute_error: 286.5185 - val_loss: 90515.3984 - val_mean_absolute_error: 300.7697
# Epoch 6/100
# 7/7 [==============================] - 0s 6ms/step - loss: 82521.7344 - mean_absolute_error: 285.5015 - val_loss: 89828.1094 - val_mean_absolute_error: 299.6250
# Epoch 7/100
# 7/7 [==============================] - 0s 6ms/step - loss: 81806.0469 - mean_absolute_error: 284.2452 - val_loss: 88907.5078 - val_mean_absolute_error: 298.0847
# Epoch 8/100
# 7/7 [==============================] - 0s 6ms/step - loss: 80793.7734 - mean_absolute_error: 282.4547 - val_loss: 87658.5234 - val_mean_absolute_error: 295.9822
# Epoch 9/100
# 7/7 [==============================] - 0s 6ms/step - loss: 79547.5000 - mean_absolute_error: 280.2318 - val_loss: 86194.3203 - val_mean_absolute_error: 293.4984
# Epoch 10/100
# 7/7 [==============================] - 0s 7ms/step - loss: 78026.8047 - mean_absolute_error: 277.5212 - val_loss: 84369.7109 - val_mean_absolute_error: 290.3734
# Epoch 11/100
# 7/7 [==============================] - 0s 6ms/step - loss: 76161.7578 - mean_absolute_error: 274.1314 - val_loss: 82130.3594 - val_mean_absolute_error: 286.4914
# Epoch 12/100
# 7/7 [==============================] - 0s 6ms/step - loss: 73908.5859 - mean_absolute_error: 269.9915 - val_loss: 79665.0547 - val_mean_absolute_error: 282.1561
# Epoch 13/100
# 7/7 [==============================] - 0s 7ms/step - loss: 71552.1562 - mean_absolute_error: 265.5844 - val_loss: 77076.9375 - val_mean_absolute_error: 277.5319
# Epoch 14/100
# 7/7 [==============================] - 0s 6ms/step - loss: 68979.4375 - mean_absolute_error: 260.7264 - val_loss: 74145.1094 - val_mean_absolute_error: 272.1987
# Epoch 15/100
# 7/7 [==============================] - 0s 8ms/step - loss: 66126.6172 - mean_absolute_error: 255.1854 - val_loss: 70989.1172 - val_mean_absolute_error: 266.3384
# Epoch 16/100
# 7/7 [==============================] - 0s 6ms/step - loss: 63014.3516 - mean_absolute_error: 248.9919 - val_loss: 67366.1250 - val_mean_absolute_error: 259.4476
# Epoch 17/100
# 7/7 [==============================] - 0s 6ms/step - loss: 59408.1055 - mean_absolute_error: 241.6313 - val_loss: 63331.5039 - val_mean_absolute_error: 251.5522
# Epoch 18/100
# 7/7 [==============================] - 0s 6ms/step - loss: 55609.0430 - mean_absolute_error: 233.6347 - val_loss: 59258.1758 - val_mean_absolute_error: 243.3212
# Epoch 19/100
# 7/7 [==============================] - 0s 6ms/step - loss: 51705.4570 - mean_absolute_error: 225.1435 - val_loss: 54960.7383 - val_mean_absolute_error: 234.3239
# Epoch 20/100
# 7/7 [==============================] - 0s 6ms/step - loss: 47477.6250 - mean_absolute_error: 215.5870 - val_loss: 50211.9414 - val_mean_absolute_error: 223.9620
# Epoch 21/100
# 7/7 [==============================] - 0s 7ms/step - loss: 43094.5664 - mean_absolute_error: 205.1204 - val_loss: 45468.8867 - val_mean_absolute_error: 213.1098
# Epoch 22/100
# 7/7 [==============================] - 0s 6ms/step - loss: 38368.2656 - mean_absolute_error: 193.1967 - val_loss: 39644.8203 - val_mean_absolute_error: 198.9763
# Epoch 23/100
# 7/7 [==============================] - 0s 6ms/step - loss: 32779.0039 - mean_absolute_error: 178.2118 - val_loss: 33903.5742 - val_mean_absolute_error: 183.9854
# Epoch 24/100
# 7/7 [==============================] - 0s 6ms/step - loss: 27843.8027 - mean_absolute_error: 163.7120 - val_loss: 28802.6699 - val_mean_absolute_error: 169.5574
# Epoch 25/100
# 7/7 [==============================] - 0s 7ms/step - loss: 23272.0293 - mean_absolute_error: 149.0920 - val_loss: 23964.4219 - val_mean_absolute_error: 154.6333
# Epoch 26/100
# 7/7 [==============================] - 0s 6ms/step - loss: 18991.1875 - mean_absolute_error: 133.9631 - val_loss: 19422.3887 - val_mean_absolute_error: 139.1737
# Epoch 27/100
# 7/7 [==============================] - 0s 6ms/step - loss: 14890.3857 - mean_absolute_error: 117.6711 - val_loss: 14882.5986 - val_mean_absolute_error: 121.7770
# Epoch 28/100
# 7/7 [==============================] - 0s 6ms/step - loss: 11224.4355 - mean_absolute_error: 100.9442 - val_loss: 11311.3555 - val_mean_absolute_error: 106.1055
# Epoch 29/100
# 7/7 [==============================] - 0s 10ms/step - loss: 8368.9189 - mean_absolute_error: 85.4127 - val_loss: 8319.2910 - val_mean_absolute_error: 90.9193
# Epoch 30/100
# 7/7 [==============================] - 0s 6ms/step - loss: 6015.9253 - mean_absolute_error: 70.6974 - val_loss: 5964.7441 - val_mean_absolute_error: 76.8881
# Epoch 31/100
# 7/7 [==============================] - 0s 7ms/step - loss: 4278.8276 - mean_absolute_error: 57.0687 - val_loss: 4136.1743 - val_mean_absolute_error: 63.9000
# Epoch 32/100
# 7/7 [==============================] - 0s 7ms/step - loss: 3021.4683 - mean_absolute_error: 45.2900 - val_loss: 2788.4722 - val_mean_absolute_error: 52.3021
# Epoch 33/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2134.2397 - mean_absolute_error: 37.1940 - val_loss: 1842.8860 - val_mean_absolute_error: 42.3074
# Epoch 34/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1584.3574 - mean_absolute_error: 32.6463 - val_loss: 1210.0859 - val_mean_absolute_error: 34.0165
# Epoch 35/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1292.6270 - mean_absolute_error: 30.3489 - val_loss: 799.6448 - val_mean_absolute_error: 27.3254
# Epoch 36/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1113.8058 - mean_absolute_error: 28.2944 - val_loss: 559.3077 - val_mean_absolute_error: 22.5020
# Epoch 37/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1053.7484 - mean_absolute_error: 27.4671 - val_loss: 412.0941 - val_mean_absolute_error: 18.9507
# Epoch 38/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1018.6096 - mean_absolute_error: 27.0142 - val_loss: 335.5435 - val_mean_absolute_error: 16.8101
# Epoch 39/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1011.2756 - mean_absolute_error: 26.8626 - val_loss: 288.4311 - val_mean_absolute_error: 15.3751
# Epoch 40/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1011.9205 - mean_absolute_error: 26.8896 - val_loss: 260.5622 - val_mean_absolute_error: 14.5134
# Epoch 41/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1010.3144 - mean_absolute_error: 26.8670 - val_loss: 256.9427 - val_mean_absolute_error: 14.3973
# Epoch 42/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1010.5242 - mean_absolute_error: 26.8715 - val_loss: 254.6140 - val_mean_absolute_error: 14.3221
# Epoch 43/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1010.5610 - mean_absolute_error: 26.8712 - val_loss: 257.0279 - val_mean_absolute_error: 14.4001
# Epoch 44/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1010.2971 - mean_absolute_error: 26.8673 - val_loss: 257.3409 - val_mean_absolute_error: 14.4101
# Epoch 45/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1010.3060 - mean_absolute_error: 26.8670 - val_loss: 257.1716 - val_mean_absolute_error: 14.4047
# Epoch 46/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1010.7005 - mean_absolute_error: 26.8710 - val_loss: 252.9034 - val_mean_absolute_error: 14.2666
# Epoch 47/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1010.9832 - mean_absolute_error: 26.8864 - val_loss: 266.2965 - val_mean_absolute_error: 14.6952
# Epoch 48/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1010.2416 - mean_absolute_error: 26.8643 - val_loss: 262.8995 - val_mean_absolute_error: 14.5878
# Epoch 49/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1010.1269 - mean_absolute_error: 26.8621 - val_loss: 259.8489 - val_mean_absolute_error: 14.4906
# Epoch 50/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1010.0870 - mean_absolute_error: 26.8629 - val_loss: 261.2527 - val_mean_absolute_error: 14.5354
# Epoch 51/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1010.2302 - mean_absolute_error: 26.8645 - val_loss: 267.7474 - val_mean_absolute_error: 14.7409
# Epoch 52/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1009.7310 - mean_absolute_error: 26.8474 - val_loss: 279.5772 - val_mean_absolute_error: 15.1086
# Epoch 53/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1008.4949 - mean_absolute_error: 26.8347 - val_loss: 271.9993 - val_mean_absolute_error: 14.8748
# Epoch 54/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1005.5554 - mean_absolute_error: 26.7900 - val_loss: 300.6043 - val_mean_absolute_error: 15.7386
# Epoch 55/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1005.1781 - mean_absolute_error: 26.7959 - val_loss: 271.0566 - val_mean_absolute_error: 14.8519
# Epoch 56/100
# 7/7 [==============================] - 0s 6ms/step - loss: 968.9378 - mean_absolute_error: 26.4433 - val_loss: 323.5244 - val_mean_absolute_error: 16.5208
# Epoch 57/100
# 7/7 [==============================] - 0s 6ms/step - loss: 947.7919 - mean_absolute_error: 26.0761 - val_loss: 430.8983 - val_mean_absolute_error: 19.5449
# Epoch 58/100
# 7/7 [==============================] - 0s 7ms/step - loss: 895.5992 - mean_absolute_error: 25.3471 - val_loss: 364.5095 - val_mean_absolute_error: 17.7774
# Epoch 59/100
# 7/7 [==============================] - 0s 7ms/step - loss: 862.5590 - mean_absolute_error: 24.7665 - val_loss: 480.3648 - val_mean_absolute_error: 20.8243
# Epoch 60/100
# 7/7 [==============================] - 0s 6ms/step - loss: 859.2496 - mean_absolute_error: 24.6828 - val_loss: 258.7817 - val_mean_absolute_error: 14.5657
# Epoch 61/100
# 7/7 [==============================] - 0s 6ms/step - loss: 817.6339 - mean_absolute_error: 24.2037 - val_loss: 309.0526 - val_mean_absolute_error: 16.2216
# Epoch 62/100
# 7/7 [==============================] - 0s 7ms/step - loss: 770.6028 - mean_absolute_error: 23.4414 - val_loss: 199.9080 - val_mean_absolute_error: 12.5756
# Epoch 63/100
# 7/7 [==============================] - 0s 6ms/step - loss: 753.8540 - mean_absolute_error: 23.0482 - val_loss: 276.3306 - val_mean_absolute_error: 15.2419
# Epoch 64/100
# 7/7 [==============================] - 0s 6ms/step - loss: 725.7625 - mean_absolute_error: 22.6391 - val_loss: 167.8810 - val_mean_absolute_error: 11.3569
# Epoch 65/100
# 7/7 [==============================] - 0s 7ms/step - loss: 700.6333 - mean_absolute_error: 22.3817 - val_loss: 193.9463 - val_mean_absolute_error: 12.4292
# Epoch 66/100
# 7/7 [==============================] - 0s 7ms/step - loss: 658.6255 - mean_absolute_error: 21.5431 - val_loss: 605.4813 - val_mean_absolute_error: 23.7654
# Epoch 67/100
# 7/7 [==============================] - 0s 6ms/step - loss: 658.9642 - mean_absolute_error: 21.4703 - val_loss: 197.8232 - val_mean_absolute_error: 12.6280
# Epoch 68/100
# 7/7 [==============================] - 0s 6ms/step - loss: 603.3926 - mean_absolute_error: 20.6407 - val_loss: 225.7236 - val_mean_absolute_error: 13.6222
# Epoch 69/100
# 7/7 [==============================] - 0s 7ms/step - loss: 577.6329 - mean_absolute_error: 20.1162 - val_loss: 138.4410 - val_mean_absolute_error: 10.2068
# Epoch 70/100
# 7/7 [==============================] - 0s 7ms/step - loss: 560.6161 - mean_absolute_error: 19.7357 - val_loss: 94.2008 - val_mean_absolute_error: 7.9747
# Epoch 71/100
# 7/7 [==============================] - 0s 6ms/step - loss: 560.6905 - mean_absolute_error: 19.6692 - val_loss: 142.1267 - val_mean_absolute_error: 10.4491
# Epoch 72/100
# 7/7 [==============================] - 0s 7ms/step - loss: 476.8864 - mean_absolute_error: 18.1854 - val_loss: 99.9575 - val_mean_absolute_error: 8.3991
# Epoch 73/100
# 7/7 [==============================] - 0s 6ms/step - loss: 438.3224 - mean_absolute_error: 17.5560 - val_loss: 221.2403 - val_mean_absolute_error: 13.6294
# Epoch 74/100
# 7/7 [==============================] - 0s 7ms/step - loss: 386.5711 - mean_absolute_error: 15.9387 - val_loss: 266.1473 - val_mean_absolute_error: 15.2586
# Epoch 75/100
# 7/7 [==============================] - 0s 7ms/step - loss: 361.0298 - mean_absolute_error: 15.6163 - val_loss: 92.5052 - val_mean_absolute_error: 8.0863
# Epoch 76/100
# 7/7 [==============================] - 0s 7ms/step - loss: 315.3712 - mean_absolute_error: 14.6190 - val_loss: 221.0729 - val_mean_absolute_error: 13.7511
# Epoch 77/100
# 7/7 [==============================] - 0s 6ms/step - loss: 301.6718 - mean_absolute_error: 14.3350 - val_loss: 326.3054 - val_mean_absolute_error: 17.1671
# Epoch 78/100
# 7/7 [==============================] - 0s 6ms/step - loss: 285.2923 - mean_absolute_error: 13.8673 - val_loss: 69.2106 - val_mean_absolute_error: 6.8288
# Epoch 79/100
# 7/7 [==============================] - 0s 7ms/step - loss: 234.5225 - mean_absolute_error: 12.4321 - val_loss: 47.9325 - val_mean_absolute_error: 5.8833
# Epoch 80/100
# 7/7 [==============================] - 0s 6ms/step - loss: 273.3770 - mean_absolute_error: 14.1933 - val_loss: 38.3292 - val_mean_absolute_error: 5.2096
# Epoch 81/100
# 7/7 [==============================] - 0s 6ms/step - loss: 207.1085 - mean_absolute_error: 11.8134 - val_loss: 38.5138 - val_mean_absolute_error: 5.2284
# Epoch 82/100
# 7/7 [==============================] - 0s 7ms/step - loss: 159.3350 - mean_absolute_error: 10.0407 - val_loss: 37.8840 - val_mean_absolute_error: 5.2154
# Epoch 83/100
# 7/7 [==============================] - 0s 7ms/step - loss: 135.6999 - mean_absolute_error: 9.0353 - val_loss: 36.8981 - val_mean_absolute_error: 5.1821
# Epoch 84/100
# 7/7 [==============================] - 0s 7ms/step - loss: 115.9106 - mean_absolute_error: 8.3925 - val_loss: 46.7691 - val_mean_absolute_error: 5.6843
# Epoch 85/100
# 7/7 [==============================] - 0s 7ms/step - loss: 103.0793 - mean_absolute_error: 7.7924 - val_loss: 31.9035 - val_mean_absolute_error: 4.9415
# Epoch 86/100
# 7/7 [==============================] - 0s 6ms/step - loss: 88.4268 - mean_absolute_error: 7.3677 - val_loss: 43.3566 - val_mean_absolute_error: 5.5573
# Epoch 87/100
# 7/7 [==============================] - 0s 6ms/step - loss: 76.4740 - mean_absolute_error: 6.6411 - val_loss: 30.4581 - val_mean_absolute_error: 4.8581
# Epoch 88/100
# 7/7 [==============================] - 0s 6ms/step - loss: 61.7668 - mean_absolute_error: 6.0245 - val_loss: 37.3343 - val_mean_absolute_error: 5.0047
# Epoch 89/100
# 7/7 [==============================] - 0s 6ms/step - loss: 56.4599 - mean_absolute_error: 5.7993 - val_loss: 60.5367 - val_mean_absolute_error: 6.1859
# Epoch 90/100
# 7/7 [==============================] - 0s 7ms/step - loss: 51.8071 - mean_absolute_error: 5.6720 - val_loss: 31.3334 - val_mean_absolute_error: 4.8034
# Epoch 91/100
# 7/7 [==============================] - 0s 6ms/step - loss: 40.5051 - mean_absolute_error: 4.9063 - val_loss: 32.5609 - val_mean_absolute_error: 4.8274
# Epoch 92/100
# 7/7 [==============================] - 0s 6ms/step - loss: 35.6790 - mean_absolute_error: 4.5579 - val_loss: 47.6795 - val_mean_absolute_error: 5.5491
# Epoch 93/100
# 7/7 [==============================] - 0s 7ms/step - loss: 30.5216 - mean_absolute_error: 4.1999 - val_loss: 44.0308 - val_mean_absolute_error: 5.3591
# Epoch 94/100
# 7/7 [==============================] - 0s 7ms/step - loss: 28.3073 - mean_absolute_error: 4.0853 - val_loss: 43.6440 - val_mean_absolute_error: 5.3447
# Epoch 95/100
# 7/7 [==============================] - 0s 6ms/step - loss: 29.8272 - mean_absolute_error: 4.3997 - val_loss: 51.7898 - val_mean_absolute_error: 5.8026
# Epoch 96/100
# 7/7 [==============================] - 0s 6ms/step - loss: 25.6060 - mean_absolute_error: 4.0448 - val_loss: 33.2148 - val_mean_absolute_error: 4.7515
# Epoch 97/100
# 7/7 [==============================] - 0s 6ms/step - loss: 23.6583 - mean_absolute_error: 3.8173 - val_loss: 34.0874 - val_mean_absolute_error: 4.7977
# Epoch 98/100
# 7/7 [==============================] - 0s 7ms/step - loss: 22.6170 - mean_absolute_error: 3.7015 - val_loss: 57.7468 - val_mean_absolute_error: 6.1090
# Epoch 99/100
# 7/7 [==============================] - 0s 6ms/step - loss: 22.3772 - mean_absolute_error: 3.7500 - val_loss: 40.8849 - val_mean_absolute_error: 5.1625
# Epoch 100/100
# 7/7 [==============================] - 0s 6ms/step - loss: 20.1076 - mean_absolute_error: 3.5788 - val_loss: 50.9077 - val_mean_absolute_error: 5.7885

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
